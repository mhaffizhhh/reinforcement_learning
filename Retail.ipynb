# %% [markdown]
# Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Import Dataset

# %%
df = pd.read_csv('data.csv')
df
# Out:
#        Retailer01  Retailer02  Retailer03  Retailer04  Retailer05  Retailer06  \
# 0               3           6           1           6           7           6
# 1               6           5           6          10           7           5
# 2               3           4           8           4           5           7
# 3               8          10           5           4           5           9
# 4               1           4           9           9           9           6
# ...           ...         ...         ...         ...         ...         ...
# 49995           1           5           5           8           4           5
# 49996           9           8           2          10           8           9
# 49997           6           1           6           9          10           7
# 49998           4           6           6           1           4           2
# 49999           2           7           1           9           3           1
#
#        Retailer07  Retailer08
# ...

# %% [markdown]
# UCB Algorithm

# %%
import math
N = len(df)
d = 8
retail_selected = []
sums_reward = [0] * d
nums_of_selection = [0] * d
total_reward = 0

for n in range(0, N):
  retail = 0
  max_upper_bound = 0
  for i in range(0, d):
    if nums_of_selection[i] > 0:
      average_reward = sums_reward[i] / nums_of_selection[i]
      delta = math.sqrt(3/2 * math.log(n + 1) / nums_of_selection[i])
      upper_bound = average_reward + delta
    else:
      upper_bound = 1e400
    if upper_bound > max_upper_bound:
      max_upper_bound = upper_bound
      retail = i
  retail_selected.append(retail)
  reward = df.values[n, retail]
  sums_reward[retail] = sums_reward[retail] + reward
  nums_of_selection[retail] = nums_of_selection[retail] + 1
  total_reward = total_reward + reward

# %% [markdown]
# Plot the results

# %%
plt.hist(retail_selected)
plt.xlabel('Retail')
plt.ylabel('Number of selection')
plt.show()
